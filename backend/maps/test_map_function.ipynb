# %%
import matplotlib.pyplot as plt
import pandas as pd
import geopandas as gpd 
from map_function import plot_choropleth

csv_path = "./data_model.csv"
shapefile_path = "/Users/macbookair/Desktop/CartographieMETFPA/carte-dynamique/backend/map with streamlit/data/shp/Limite des région 2018.shp"

df = pd.read_csv(csv_path)
gdf = gpd.read_file(shapefile_path)

# Join data from dataframe B with dataframe A
merged = pd.merge(df, gdf, left_on='region', right_on='Name', how='inner')

fig = plot_choropleth(
    geodf=merged,
    column_to_plot='data',         
    label_column='Name',           
    label_title='Valeur aléatoire',
    title='Carte des régions selon la donnée',
    cmap='viridis',
    size=1.5
)
plt.show()

# %%
print(gdf)
# Out:
#                                  Name                   Zone  \
# 0                       Agneby-Tiassa  Zone sans coopérative
# 1                              Bafing         Zone avec coop
# 2                              Bagoue         Zone avec coop
# 3                              Belier         Zone avec coop
# 4                                Bere         Zone avec coop
# 5                            Bounkani         Zone avec coop
# 6                             Cavally  Zone sans coopérative
# 7         District Autonome D'Abidjan  Zone sans coopérative
# 8   District Autonome De Yamoussoukro         Zone avec coop
# 9                               Folon         Zone avec coop
# 10                              Gbeke         Zone avec coop
# 11                             Gbokle  Zone sans coopérative
# 12                                Goh  Zone sans coopérative
# 13                           Gontougo         Zone avec coop
# 14                       Grands Ponts  Zone sans coopérative
# 15                             Guemon  Zone sans coopérative
# 16                             Hambol         Zone avec coop
# 17                     Haut-Sassandra  Zone sans coopérative
# 18                              Iffou  Zone sans coopérative
# 19                   Indenie-Djuablin  Zone sans coopérative
# 20                         Kabadougou         Zone avec coop
# 21                        Loh-Djiboua  Zone sans coopérative
# 22                           Marahoue         Zone avec coop
# 23                                 Me  Zone sans coopérative
# 24                            Moronou  Zone sans coopérative
# 25                               N'Zi         Zone avec coop
# 26                               Nawa  Zone sans coopérative
# 27                               Poro         Zone avec coop
# 28                          San Pedro  Zone sans coopérative
# 29                          Sud-Comoe  Zone sans coopérative
# 30                           Tchologo         Zone avec coop
# 31                             Tonkpi         Zone avec coop
# 32                         Worodougou         Zone avec coop
#
#                                              geometry
# 0   POLYGON Z ((-5.09329 6.28721 0, -5.09087 6.284...
# 1   POLYGON Z ((-7.77733 9.06986 0, -7.77525 9.069...
# 2   POLYGON Z ((-6.23341 10.73216 0, -6.23138 10.7...
# 3   MULTIPOLYGON Z (((-5.03551 6.7668 0, -5.0331 6...
# 4   POLYGON Z ((-6.32844 9.20994 0, -6.32627 9.208...
# 5   POLYGON Z ((-3.61343 9.95807 0, -3.59332 9.937...
# 6   POLYGON Z ((-7.99312 6.97954 0, -7.98109 6.972...
# 7   POLYGON Z ((-4.16993 5.60041 0, -4.16825 5.600...
# 8   POLYGON Z ((-5.29206 7.07251 0, -5.29038 7.071...
# 9   POLYGON Z ((-7.58912 10.42736 0, -7.5765 10.42...
# 10  POLYGON Z ((-5.36916 8.1043 0, -5.36615 8.1036...
# 11  POLYGON Z ((-6.20056 5.62672 0, -6.19925 5.626...
# 12  POLYGON Z ((-5.42525 6.64825 0, -5.42272 6.648...
# 13  POLYGON Z ((-2.5831 8.78338 0, -2.57995 8.7625...
# 14  POLYGON Z ((-4.91522 5.76587 0, -4.91275 5.764...
# 15  POLYGON Z ((-7.1171 7.7219 0, -7.11543 7.72126...
# 16  POLYGON Z ((-5.18977 9.41186 0, -5.18975 9.409...
# 17  POLYGON Z ((-6.53276 7.76669 0, -6.46198 7.735...
# 18  POLYGON Z ((-3.98839 8.02485 0, -3.9871 8.0243...
# 19  POLYGON Z ((-3.47223 7.34368 0, -3.47059 7.343...
# 20  POLYGON Z ((-7.67436 9.9936 0, -7.67291 9.9930...
# 21  POLYGON Z ((-5.30401 6.2691 0, -5.30141 6.2690...
# 22  POLYGON Z ((-5.97166 7.74769 0, -5.97026 7.746...
# 23  POLYGON Z ((-3.68308 6.62502 0, -3.68346 6.623...
# 24  POLYGON Z ((-4.01629 6.99874 0, -4.01528 6.998...
# 25  POLYGON Z ((-4.64279 7.47726 0, -4.64121 7.476...
# 26  POLYGON Z ((-6.98251 6.55361 0, -6.98121 6.552...
# 27  POLYGON Z ((-5.80168 10.37476 0, -5.80376 10.3...
# 28  POLYGON Z ((-7.07054 5.64351 0, -7.06879 5.641...
# 29  POLYGON Z ((-3.11099 6.15611 0, -3.08277 5.998...
# 30  POLYGON Z ((-5.64715 10.45751 0, -5.64513 10.4...
# 31  POLYGON Z ((-7.43561 8.15297 0, -7.43608 8.151...
# 32  POLYGON Z ((-6.75399 9.11879 0, -6.75169 9.118...
